# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer 
import joblib
from random import randint

def predict_car_prices(X, y):
    model = LinearRegression()
    model.fit(X, y) 
    print("model score = {}".format(model.score(X, y)))
    
    joblib.dump(model, 'car_prices_model+' + str(randint(1, sys.maxsize)))
    
    print(model.predict([[45000, 4, 0, 0]])) 
    print(model.predict([[86000, 7, 0, 1]])) 
    

df = pd.read_csv("~/code/py/ML/5_one_hot_encoding/Exercise/carprices.csv")

# Using get_dummies for one hot encoding 
df1 = pd.get_dummies(df, 'Car Model')
X = df1.drop(columns = ['Car Model_Mercedez Benz C class', 'Sell Price($)'])
y = df1['Sell Price($)']
predict_car_prices(X, y) 

# Using ColumnTransformer and OneHotEncoder 
categorical_features = ['Car Model']
preprocessor = ColumnTransformer(transformers = [('onehot', OneHotEncoder(), categorical_features)], remainder = "passthrough") 
df = pd.DataFrame(preprocessor.fit_transform(df), columns = preprocessor.get_feature_names_out())
X = df[['remainder__Mileage', 'remainder__Age(yrs)', 'onehot__Car Model_Audi A5', 'onehot__Car Model_BMW X5']]
y = df['remainder__Sell Price($)'] 
predict_car_prices(X, y)
# Out:
# model score = 0.9417050937281083
# [36991.31721061]
# [11080.74313219]
# model score = 0.9417050937281083
# [36991.31721061]
# [11080.74313219]
# /Users/sidreddy/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Users/sidreddy/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Users/sidreddy/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Users/sidreddy/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
# ...
